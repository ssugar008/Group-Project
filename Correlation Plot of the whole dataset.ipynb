# %%
import pandas as pd
movie_2015_2016 = pd.read_csv('final_database_2015_2016.csv', encoding = 'ISO-8859-1')

# %%
combined_2015_2016 = pd.read_csv('final_database_2015_2016.csv', encoding = 'ISO-8859-1')
combined_2015_2016.columns = ['useless', 'Actor1 Id', 'Actor1 Name', 'Actor2 Id', 'Actor2 Name',
       'Actor3 Id', 'Actor3 Name', 'Popularity', 'Release Date', 'Text',
       'Title', 'Vote Average', 'Vote Count', 'adult', 'backdrop_path',
       'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
       'imdb_id', 'original_language', 'original_title', 'overview',
       'poster_path', 'production_companies', 'production_countries',
       'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
       'tagline', 'video', 'useless1', 'useless2']
combined_2015_2016 = combined_2015_2016.drop('useless',1)
combined_2015_2016 = combined_2015_2016.drop('useless1',1)
combined_2015_2016 = combined_2015_2016.drop('useless2',1)

# %%
combined_2015_2016['Length of all Comments'] = len(combined_2015_2016['Text'])
for i in range(1028):
    combined_2015_2016['Length of all Comments'].iloc[i] = len(combined_2015_2016['Text'].iloc[i])
combined_2015_2016
# Out:
# C:\Users\Moses\Anaconda3\envs\pyv4\lib\site-packages\pandas\core\indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#       Actor1 Id            Actor1 Name  Actor2 Id           Actor2 Name  \
# 0     1046143.0             Caity Lotz    17271.0         Brandon Routh
# 1       44079.0     Charlotte Rampling    14011.0         Tom Courtenay
# 2      527313.0         Taissa Farmiga  1088672.0        Ben Rosenfield
# 3        3063.0          Tilda Swinton    73381.0  Matthias Schoenaerts
# 4        6860.0          Jimmy Bennett    76226.0        Lexi Ainsworth
# 5       32684.0          Rolf Lassg?rd    99522.0            Bahar Pars
# 6       18182.0         Olga Kurylenko     1121.0      Benicio del Toro
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr = combined_2015_2016.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, annot=True)
plt.show()
