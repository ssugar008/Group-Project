# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd

# %%
def create_word_features(words):
    useful_words = [word for word in words if word not in stopwords.words("english")]
    my_dict = dict([(word, True) for word in useful_words])
    return my_dict

# %%
create_word_features(["the", "quick", "brown", "quick", "a", "fox"])
# Out:
# {'brown': True, 'fox': True, 'quick': True}

# %%
neg_reviews = []
pos_reviews = []

for fileid in movie_reviews.fileids('neg'):
    words = movie_reviews.words(fileid)
    neg_reviews.append((create_word_features(words), "negative"))

for fileid in movie_reviews.fileids('pos'):
    words = movie_reviews.words(fileid)
    pos_reviews.append((create_word_features(words), "positive"))
    
print(len(pos_reviews), len(neg_reviews))
# Out:
# 1000 1000

# %%
train_set = neg_reviews + pos_reviews

# %%
classifier = NaiveBayesClassifier.train(train_set)

# %%
train_set[-1]
# Out:
# ({'"': True,
#   "'": True,
#   '(': True,
#   ')': True,
#   ',': True,
#   '-': True,
#   '.': True,
#   '/': True,
#   ';': True,
#   '?': True,
#   'accident': True,
#   'actions': True,
#   'address': True,
#   'airplane': True,
#   'almost': True,
#   'also': True,
#   'although': True,
#   'amazing': True,
#   'americans': True,
#   'andrew': True,
#   'announcer': True,
#   'another': True,
#   'answer': True,
#   'apart': True,
#   'apparently': True,
#   'appears': True,
#   'around': True,
#   'aroused': True,
#   'artificial': True,
#   'asked': True,
#   'attack': True,
#   'awakening': True,
#   'back': True,
#   'beautiful': True,
#   'became': True,
#   'becomes': True,
#   'behind': True,
#   'best': True,
#   'better': True,
#   'big': True,
#   'breaks': True,
#   'brings': True,
#   'brisk': True,
#   'building': True,
#   'built': True,
#   'burbank': True,
#   'cage': True,
#   'california': True,
#   'came': True,
#   'cameo': True,
#   'camera': True,
#   'cameras': True,
#   'capitalized': True,
#   'captive': True,
#   'car': True,
#   'cards': True,
#   'carefully': True,
#   'carrey': True,
#   'carrying': True,
#   'center': True,
#   'certainly': True,
#   'change': True,
#   'chaos': True,
#   'character': True,
#   'choice': True,
#   'chosen': True,
#   'christof': True,
#   'classic': True,
#   'clicked': True,
#   'coffee': True,
#   'coincidence': True,
#   'combine': True,
#   'comes': True,
#   'coming': True,
#   'communities': True,
#   'compare': True,
#   'competently': True,
#   'concept': True,
#   'concepts': True,
#   'corners': True,
#   'counting': True,
#   'covering': True,
#   'creator': True,
#   'criticize': True,
#   'day': True,
#   'deal': True,
#   'death': True,
#   'describes': True,
#   'determined': True,
#   'dinosaurs': True,
#   'director': True,
#   'disappointed': True,
#   'distracted': True,
#   'door': True,
#   'doors': True,
#   'drama': True,
#   'dream': True,
#   'drive': True,
#   'driven': True,
#   'earlier': True,
#   'easily': True,
#   'edge': True,
#   'elaborate': True,
#   'elevator': True,
#   'else': True,
#   'end': True,
#   'ends': True,
#   'enters': True,
#   'entire': True,
#   'epic': True,
#   'era': True,
#   'escape': True,
#   'ethics': True,
#   'even': True,
#   'every': True,
#   'everything': True,
#   'exactly': True,
#   'exclusive': True,
#   'expense': True,
#   'explaining': True,
#   'explains': True,
#   'fair': True,
#   'fake': True,
#   'falling': True,
#   'falls': True,
#   'family': True,
#   'father': True,
#   'fear': True,
#   'felt': True,
#   'film': True,
#   'films': True,
#   'find': True,
#   'first': True,
#   'following': True,
#   'forward': True,
#   'found': True,
#   'frantic': True,
#   'functioning': True,
#   'gattaca': True,
#   'get': True,
#   'gets': True,
#   'glass': True,
#   'got': True,
#   'government': True,
#   'grab': True,
#   'great': True,
#   'green': True,
#   'grim': True,
#   'grip': True,
#   'guards': True,
#   'handled': True,
#   'happens': True,
#   'happy': True,
#   'help': True,
#   'hidden': True,
#   'hits': True,
#   'hoax': True,
#   'hollywood': True,
#   'home': True,
#   'hope': True,
#   'idea': True,
#   'ideas': True,
#   'idyllic': True,
#   'impact': True,
#   'instant': True,
#   'interesting': True,
#   'interviews': True,
#   'introduces': True,
#   'jams': True,
#   'jim': True,
#   'jurassic': True,
#   'keep': True,
#   'keeping': True,
#   'keyboardist': True,
#   'know': True,
#   'known': True,
#   'last': True,
#   'leads': True,
#   'learning': True,
#   'led': True,
#   'life': True,
#   'light': True,
#   'like': True,
#   'listeners': True,
#   'little': True,
#   'lives': True,
#   'long': True,
#   'look': True,
#   'looking': True,
#   'lounge': True,
#   'lower': True,
#   'made': True,
#   'man': True,
#   'may': True,
#   'meanwhile': True,
#   'memory': True,
#   'mind': True,
#   'missed': True,
#   'movements': True,
#   'moves': True,
#   'movie': True,
#   'much': True,
#   'music': True,
#   'name': True,
#   'names': True,
#   'nbc': True,
#   'nearly': True,
#   'necessary': True,
#   'neither': True,
#   'nevertheless': True,
#   'next': True,
#   'niccol': True,
#   'normal': True,
#   'numbers': True,
#   'nurse': True,
#   'obscuring': True,
#   'obstructions': True,
#   'ocean': True,
#   'oddities': True,
#   'office': True,
#   'one': True,
#   'open': True,
#   'opens': True,
#   'opportunities': True,
#   'opus': True,
#   'overall': True,
#   'overflying': True,
#   'pacing': True,
#   'pain': True,
#   'paneled': True,
#   'park': True,
#   'part': True,
#   'particularly': True,
#   'pedestrian': True,
#   'people': True,
#   'perfect': True,
#   'performance': True,
#   'perhaps': True,
#   'permeates': True,
#   'person': True,
#   'philip': True,
#   'pick': True,
#   'picking': True,
#   'picture': True,
#   'place': True,
#   'planned': True,
#   'plenty': True,
#   'plot': True,
#   'point': True,
#   'powaqqatsi': True,
#   'president': True,
#   'program': True,
#   'promised': True,
#   'properly': True,
#   'protagonist': True,
#   'psychological': True,
#   'quality': True,
#   'quell': True,
#   'questions': True,
#   'quick': True,
#   'quickly': True,
#   'radio': True,
#   'real': True,
#   'reality': True,
#   'really': True,
#   'recalls': True,
#   'right': True,
#   'robots': True,
#   'root': True,
#   'sail': True,
#   'sake': True,
#   'saw': True,
#   'says': True,
#   'scene': True,
#   'scenes': True,
#   'scientists': True,
#   'score': True,
#   'scored': True,
#   'screen': True,
#   'scripted': True,
#   'security': True,
#   'see': True,
#   'seeing': True,
#   'seemed': True,
#   'seems': True,
#   'sees': True,
#   'set': True,
#   'setup': True,
#   'shot': True,
#   'show': True,
#   'showed': True,
#   'sight': True,
#   'sign': True,
#   'sky': True,
#   'slows': True,
#   'small': True,
#   'smidgen': True,
#   'snoots': True,
#   'something': True,
#   'sooner': True,
#   'sort': True,
#   'sound': True,
#   'sounds': True,
#   'spite': True,
#   'square': True,
#   'started': True,
#   'starts': True,
#   'stature': True,
#   'still': True,
#   'stopped': True,
#   'stories': True,
#   'story': True,
#   'straight': True,
#   'studio': True,
#   'subject': True,
#   'subjecting': True,
#   'suspicion': True,
#   'suspicious': True,
#   'take': True,
#   'tangerine': True,
#   'television': True,
#   'terms': True,
#   'theme': True,
#   'theory': True,
#   'think': True,
#   'throw': True,
#   'timbre': True,
#   'title': True,
#   'token': True,
#   'told': True,
#   'tonight': True,
#   'town': True,
#   'trap': True,
#   'trauma': True,
#   'tries': True,
#   'trouble': True,
#   'true': True,
#   'truman': True,
#   'truth': True,
#   'try': True,
#   'trying': True,
#   'turn': True,
#   'tv': True,
#   'two': True,
#   'type': True,
#   'unassuming': True,
#   'unaware': True,
#   'unnecessarily': True,
#   'vainly': True,
#   'view': True,
#   'voice': True,
#   'wanders': True,
#   'war': True,
#   'warns': True,
#   'way': True,
#   'weir': True,
#   'well': True,
#   'westworld': True,
#   'whatever': True,
#   'whether': True,
#   'wife': True,
#   'wondering': True,
#   'work': True,
#   'world': True,
#   'worlds': True,
#   'worldwide': True,
#   'worse': True,
#   'would': True,
#   'writer': True,
#   'written': True},
#  'positive')

# %%
classifier.classify(create_word_features(word_tokenize("Spirited Away' is the first Miyazaki I have seen, but from this stupendous film I can tell he is a master storyteller. A hallmark of a good storyteller is making the audience empathise or pull them into the shoes of the central character. Miyazaki does this brilliantly in 'Spirited Away'. During the first fifteen minutes we have no idea what is going on. Neither does the main character Chihiro. We discover the world as Chihiro does and it's truly amazing to watch. But Miyazaki doesn't seem to treat this world as something amazing. The world is filmed just like our workaday world would. The inhabitants of the world go about their daily business as usual as full with apathy as us normal folks. Places and buildings are not greeted by towering establishing shots and majestic music. The fact that this place is amazing doesn't seem to concern Miyazaki.What do however, are the characters. Miyazaki lingers upon the characters as if they were actors. He infixes his animated actors with such subtleties that I have never seen, even from animation giants Pixar. Twenty minutes into this film and I completely forgot these were animated characters; I started to care for them like they were living and breathing. Miyazaki treats the modest achievements of Chihiro with unashamed bombast. The uplifting scene where she cleanses the River God is accompanied by stirring music and is as exciting as watching gladiatorial combatants fight. Of course, by giving the audience developed characters to care about, the action and conflicts will always be more exciting, terrifying and uplifting than normal, generic action scenes.")))
# Out:
# 'positive'

# %%
comments = pd.read_csv('commentsv1.csv',encoding = "ISO-8859-1")

# %%
comments.head()
# Out:
#   Unnamed: 0                                         Coco Bunny  \
# 0     video1  The first 6:00 minutes she spent talking about...
#
#               Steve Bagel                                  navilovesbeauty24  \
# 0  I love her vlogs!!!!!!  in love with ur new rooms!! have fun this year...
#
#                                        Taryn Carroll  \
# 0  Love the Clemson shirt you wore! (I row for cl...
#
#                         Mackenzie McGill  \
# 0  yay I'm so happy you guys uploaded:))
#
#                                        summer parent  \
# 0  Oh my gosh I shop at urban lulus and brandy we...
#
#                                      Emily Albertson  \
# 0  Do you use your Hunter Boots regularly??? I am...
#
#                                Shelby B  \
# 0  I'VE BEEN WAITING SO LONG FOR THISSS
#
#                                            Teri Lynn  \
# 0  Your Mom didn't come. Love your new suite. Goo...
#
#                      ...                     \
# 0                    ...
#
#                      basically becca  \
# 0  loveeeee these types of vlogs!!!!
#
#                                          Maggie Bies  \
# 0  Girl! Wildfox lets you use UNiDAYS too!!! Eith...
#
#                                            MRTMRTROX  \
# 0  I literally had the exact same thing happen to...
#
#                                          serendipity  \
# 0  Hi Gretchen!  I'm a freshman in high school li...
#
#                   Shannor Becaroo  \
# 0  your eyebrows are so far apart
#
#                                         Olivia Bogan Eve C  \
# 0  Gretchen plleeeaaseee do a meetup in Boston!! ...    Hi
#
#                    Annie Rius               oneofakindbeautiful  \
# 0  good luck this year!!!!!!!  Can you do one for Lucy's dorm?!
#
#                                   Kate Watt
# 0  Going to Boston tomorrow for a 10k!! :))
#
# [1 rows x 264 columns]

# %%
sample = comments.iloc[:,1:]

# %%
sample
# Out:
#                                           Coco Bunny             Steve Bagel  \
# 0  The first 6:00 minutes she spent talking about...  I love her vlogs!!!!!!
#
#                                    navilovesbeauty24  \
# 0  in love with ur new rooms!! have fun this year...
#
#                                        Taryn Carroll  \
# 0  Love the Clemson shirt you wore! (I row for cl...
#
#                         Mackenzie McGill  \
# 0  yay I'm so happy you guys uploaded:))
#
#                                        summer parent  \
# 0  Oh my gosh I shop at urban lulus and brandy we...
#
#                                      Emily Albertson  \
# 0  Do you use your Hunter Boots regularly??? I am...
#
#                                Shelby B  \
# 0  I'VE BEEN WAITING SO LONG FOR THISSS
#
#                                            Teri Lynn  \
# 0  Your Mom didn't come. Love your new suite. Goo...
#
#                                               leo af  \
# 0  I have a Fjallraven Kankrn and I love it!!! Im...
#
#                      ...                     \
# 0                    ...
#
#                      basically becca  \
# 0  loveeeee these types of vlogs!!!!
#
#                                          Maggie Bies  \
# 0  Girl! Wildfox lets you use UNiDAYS too!!! Eith...
#
#                                            MRTMRTROX  \
# 0  I literally had the exact same thing happen to...
#
#                                          serendipity  \
# 0  Hi Gretchen!  I'm a freshman in high school li...
#
#                   Shannor Becaroo  \
# 0  your eyebrows are so far apart
#
#                                         Olivia Bogan Eve C  \
# 0  Gretchen plleeeaaseee do a meetup in Boston!! ...    Hi
#
#                    Annie Rius               oneofakindbeautiful  \
# 0  good luck this year!!!!!!!  Can you do one for Lucy's dorm?!
#
#                                   Kate Watt
# 0  Going to Boston tomorrow for a 10k!! :))
#
# [1 rows x 263 columns]

# %%
def analyzeText(value):
    return classifier.classify(create_word_features(word_tokenize(value)))

# %%
sample.iloc[0,0]
# Out:
# 'The first 6:00 minutes she spent talking about urban outfitters and clothing ?'

# %%
for i in range(0,len(sample.columns)):
    print(sample.iloc[0,i])
    print(analyzeText(sample.iloc[0,i]))
    print("...........")
# Out:
# The first 6:00 minutes she spent talking about urban outfitters and clothing ?
# negative
# ...........
# I love her vlogs!!!!!!
# negative
# ...........
# in love with ur new rooms!! have fun this year, and good luck :))
# positive
# ...........
# Love the Clemson shirt you wore! (I row for clemson!!).  Love your  suite.  So lucky ya get a view of the charles!!
# positive
# ...........
# yay I'm so happy you guys uploaded:))
# negative
# ...........
# Oh my gosh I shop at urban lulus and brandy we get it stop talking about it! Still love you tho
# negative
# ...........
# Do you use your Hunter Boots regularly??? I am going to be a freshman this year in Seattle and I am thinking about getting a pair but a lot of my friends have said they don't use them a lot!
# negative
# ...........
# I'VE BEEN WAITING SO LONG FOR THISSS
# positive
# ...........
# Your Mom didn't come. Love your new suite. Good Luck with everything this year.
# positive
# ...........
# I have a Fjallraven Kankrn and I love it!!! Im gonna ordet a mini one for traveling
# positive
# ...........
# eeeek your Clemson shirt!!
# positive
# ...........
# Why tf does a white American girl with ugly eyebrows have a Swedish backpack
# positive
# ...........
# @ daddy wheres your vlog channel!!
# negative
# ...........
# @gretchenlovesbeauty Where can I get the new york city skyline tapestry that you have?
# positive
# ...........
# Are you going to do dorm room tour ??? Your room already looks SOO good
# negative
# ...........
# Where did you get the flannel scarf hanging on your door?? I've looked everywhere for one!
# negative
# ...........
# Video actually starts at 6:50
# negative
# ...........
# girl omg can u talk and faster?! like calm down the camera isn't gonna walk away from you. take a breath and calm yourself! jeez
# positive
# ...........
# Even though you aren't rowing are you still going to HOCR?
# negative
# ...........
# OMG....can you talk ANY faster???
# negative
# ...........
# she was so annoying
# negative
# ...........
# yessss it's finally up!! I've been checking your YouTube every single day to see if it's been posted! I'm so happy omg
# positive
# ...........
# she has to start wearing eye shadow
# negative
# ...........
# Wow great idea to tell people where you're living online
# positive
# ...........
# I haven't heard someone use the full "Commonwealth Ave" in so long omg haha #truebostonian
# negative
# ...........
# Gretchen!! I absolutely love all of your videos, especially the college ones! I'm a senior in high school and I'm about to make a decision for what college to attend! Please keep making more and more college videos, they're so helpful and I LOVE them!! ??
# positive
# ...........
# Can Taylor do a room tour and what's on my iPhone!????
# positive
# ...........
# UGH so happy this vlog is out! <33333 love you beyond words gretchen (and lucy) :)
# positive
# ...........
# What's the album ?
# negative
# ...........
# the new balance building and bruins practice arena are so close to my house! i drive past there on the way to boston all the time!
# positive
# ...........
# Ughhh so jealous you guys live in Boston. I'm a huge Bruins fan. Go to a game for me!
# negative
# ...........
# do a dorm tour!!!
# negative
# ...........
# girl.. ill pray for your brows
# negative
# ...........
# Please do a Dorm Room Tour!!!
# negative
# ...........
# YES YES YES GOOD LUCK THIS YEAR!!!
# negative
# ...........
# I have the same bedspread as Taylor!!!
# negative
# ...........
# Ive been waiting for this video for so long!! :)
# negative
# ...........
# BOSTONIAN REPPIN' ?????????????????????????????????
# negative
# ...........
# someone's got money...
# negative
# ...........
# ahh sorry but this was too much ad for me :/
# negative
# ...........
# Omg stuvi 2 is amazing!! My brother had a suite there for two years and then had an apartment style his senior year! I also go to the high school right on BU's campus... Hopefully I'll see you around!
# positive
# ...........
# Do another college room tour once you have moved in?
# positive
# ...........
# EastonTennis would love the multiple Taylor appearances where ya at Easton
# positive
# ...........
# I enjoyed the move  in vlog <3 i love you gretchen
# positive
# ...........
# I literally get so excited about these college videos omg haha
# positive
# ...........
# Can I just say she never stops talking
# positive
# ...........
# What are Lucy and Taylor majoring in?
# positive
# ...........
# This girl looks like half Alisha Marie and half gabi from niki and gabi
# negative
# ...........
# YAY LOVE THESE
# positive
# ...........
# Please vlog a lot while your at collage!!
# positive
# ...........
# omg bu is my dream college but im prob not gonna get in cuz i got shit grades ?
# positive
# ...........
# I don't understand why you and your sister aren't roommates.
# positive
# ...........
# i go to bu too!!
# negative
# ...........
# Gretchen you're so beautiful and where is the necklace from you're wearing when you're talking about the record player?
# positive
# ...........
# I go to school in central mass but go into boston every other weekend! I lived there last year! Maybe I'll run into you one day haha
# positive
# ...........
# I've had the worst day today and this cheered me up so much, love you. ?
# negative
# ...........
# where did you get your new york city skyline tapestry?
# positive
# ...........
# Gabi*
# positive
# ...........
# your old room mate has my name makya
# negative
# ...........
# loooove your dorm!!
# negative
# ...........
# Anyone else notice how she kept moving her hair it was kinda annoying and a little distracting from the video and it kinda got on my nerves but I'm not hating I'm just speak my opinion which I am can say I'm not saying that it is bad I just don't like when she moves her hair
# negative
# ...........
# aww I love your videos soooo much. Favorite youtuber!!!
# positive
# ...........
# I just transferred to Radford University as a Sophomore too! ahah I love watching other youtubers move in vlogs. I didnt get to do one this year :(
# negative
# ...........
# ilysm!! ?
# negative
# ...........
# why the hell was half of this vlog a promo?? you're defs not getting a sub from me.
# negative
# ...........
# What's the album called that you were playing
# negative
# ...........
# finally!! i love you and lucy so so much ??
# negative
# ...........
# Enjoyed this video so much and love your dad btw ?
# negative
# ...........
# what camera does she use?
# negative
# ...........
# where's her mom?????
# negative
# ...........
# where's your mom if you don't mind me asking?
# negative
# ...........
# i'm visiting BU in the spring because i want to apply! seems like an awesome school
# positive
# ...........
# Half the video u weren't even moving in??
# positive
# ...........
# your dorm layout is so nice!!
# negative
# ...........
# She moved in at 13:00
# positive
# ...........
# I've been waiting forever and a day for this vlog! ???
# negative
# ...........
# came straight from Twitter after seeing your tweet about this vlog!!
# negative
# ...........
# can you show how you're eating vegan in college? like maybe what i eat in a day or something :))
# negative
# ...........
# Oh my gosh. You're living in Stuvi 2?! Ugh so many good memories. The best dorm EVER!
# negative
# ...........
# BRITISH UNI STUDENTS can sign up to uni days here myunidays.com/r/BFTFk6gKOog and enter similar contests, there are ones for TV's, ¢G200 clothing vouchers & more!
# negative
# ...........
# you do know if you're doing an ad for a company or it is sponsored you need to say this either in the video or in your description box. youtube is getting strict with these rules and if you dont comply your videos will be deleted
# negative
# ...........
# love the clemson sc shirt
# positive
# ...........
# what's the name if the type of joggers?!?!?! helpp
# negative
# ...........
# For your dorm room tour you should show the common area! I'd love to see how it turns out! :)
# positive
# ...........
# omg your eye brows girl....................
#
#
#
#
#
#
#
# I could do division on them.
# positive
# ...........
# ahhhh I love alt j!!!
# negative
# ...........
# omg!! I love you Clemson shirt! I live like 20 minutes away from there and I am a huge Clemson fan that's so cool! haha!
# negative
# ...........
# is she still dating justin?
# negative
# ...........
# AWW OMG I love this ????
# negative
# ...........
# Any new YouTubers wanna support each other? I'LL SUB BACK! ??
# positive
# ...........
# Why didn't you guys drive? Won't you need a car?
# negative
# ...........
# Why are your eyebrows so far apart?
# positive
# ...........
# Do more vlogs
# positive
# ...........
# So that's why I waited in the minivan at the curb for two hours....?
# positive
# ...........
# Yay I'm early!
# negative
# ...........
# Please do a workout routine and more vegan food videos!!!???
# negative
# ...........
# She looks like Alisha Marie and Nicki from Nicki and gabbi ????
# negative
# ...........
# Dates are so good :)
# negative
# ...........
# omg this girl talks alot and says omg alot it's annoying
# positive
# ...........
# When i saw this it had 1,666 views so i couldn't wait another second
# positive
# ...........
# Throwback to eastontennis! He'll be happy she'll be with Taylor all the time lol
# negative
# ...........
# September 3rd was actually my birthday ! ?
# positive
# ...........
# Her friends and dad are like" shut the hell up" lol
# negative
# ...........
# I know it's early but I'm already so excited for your vlogmas
# positive
# ...........
# where is your new square necklace from?? IM OBSESSED
# positive
# ...........
# love you gretchen! you make my day :)
# positive
# ...........
# the entire first half of this video was a unidays sponsorship... i regret wasting my time lol
# negative
# ...........
# I'm looking into going to BU next year and this video is making me so excited! hope you have a great year.
# positive
# ...........
# you can get those joggers at Walmart for anyone who wanted them but most of those  places that selll stuff like that cost to much
# negative
# ...........
# i'm so happy there is a video about boston bc all the other videos are across the country
# positive
# ...........
# Good Luck Gretchen, love you?
# negative
# ...........
# I'm in college too and I seriously feel like we could be best friends ? that building is so nice!!
# positive
# ...........
# Ugh I started college August 22nd. ??
# negative
# ...........
# I wish the majority of this was actually the vlog :/
# positive
# ...........
# did anyone else notice the handprint when she touched her chest at 1:42 hahah gretchen you're so sunburned
# positive
# ...........
# so jealous... i just graduated college in may and having withdrawals
# positive
# ...........
# So are all suites single bedrooms ?
# negative
# ...........
# Ur eyebrows would look better if they were closer together...
# positive
# ...........
# can we see lucy's dorm??
# negative
# ...........
# she rambles about the most irrelevant things.
# negative
# ...........
# dorm room tour!!!!!!!!!
# negative
# ...........
# I just found your channel today and I love your content!! I'm a junior in high school and my dream is to go to BU! But I live all the way in Texas! But ya love your videos!!
# positive
# ...........
# fallraven.... ahahahaha... Not close to right... Fj?ll-Ra-ven.
# positive
# ...........
# good luck this year ?????
# negative
# ...........
# Why do you look like lilo from lilo and stitch
# positive
# ...........
# Shut**
# positive
# ...........
# 2:07 at the start of move in xx
# negative
# ...........
# I love when she said I I like it a lot
# positive
# ...........
# I HAVE BEEN WAITING FOR THIS !!!!
# negative
# ...........
# OMG your dad is adorable
# positive
# ...........
# My brother graduated from BU this year
# positive
# ...........
# sorry but it really annoyed me that u played with your hair all the time
# negative
# ...........
# Ur dad seem so nice!
# negative
# ...........
# Gretchen just casually getting room ideas from Taylor lol.
# negative
# ...........
# Show us the view at night !!
# positive
# ...........
# she kinda reminds me of Niki lol
# negative
# ...........
# what size did u get ur joggers in
# positive
# ...........
# @ 3:55 i love those bpacks
# positive
# ...........
# Your dorm room is always so cute! Good luck this year!
# Also was wondering how that record/vinyl player is working. I heard some suck with volume but was wondering if you like the one you got!
# negative
# ...........
# Haha it's pronounced more like "f-yell-rayven" if that makes sense. It's a Swedish brand. One Piece (where your trousers are from) is a Norwegian brand I think.
# negative
# ...........
# could you make a video all about your life at BU like socially and academically because im really interested in going there next year and it would be really nice to compare it to my other top schools.
# negative
# ...........
# I see that building all the time when I'm rowing!!
# negative
# ...........
# Taylor's rooms always look so cute:)
# positive
# ...........
# TAYLOR'S ROOM IM OBSESSED
# positive
# ...........
# I have the same dolce and gabana perfume as you in light blue! it's smells soo good
# negative
# ...........
# you know who she reminds me of?
# Alisha and nicki as one person.
# positive
# ...........
# R u sponsored ?
# negative
# ...........
# Awww YAYA !! Back to college vlogs !! I love youuuu?
# negative
# ...........
# I love you so much, I have been there since your first video I love you so very much xxxxx
# negative
# ...........
# U talk rlly damn fast to much coffee
# negative
# ...........
# Omg I love u so much I live in Boston!!!
# positive
# ...........
# I think. Your video is so good but you talk a lot ?
# negative
# ...........
# Wow it's so weird seeing one of ur fav youtubers in a place you've been all over before, it's like someone recording your hometown it's just weird but in the best way! So sick you get to go there, we're the same age but you got your life together hella well girl. Congrats love you and Lucy ??????
# positive
# ...........
# I love you so much! Good luck!!! ??
# negative
# ...........
# When your eyebrows had an argument
# positive
# ...........
# do you have a kitchen in your suite?
# positive
# ...........
# Guys she kinda looks like Niki!. From niki and Gavin
# negative
# ...........
# That's such a nice dorm building
# negative
# ...........
# Boston is my dream school and I'm giving myself false hope of getting in by watching BU dorm tour videos
# positive
# ...........
# Room looks amazing already ?
# negative
# ...........
# When will the tour go up? ??
# positive
# ...........
# The briuns arena is the new practice arena it's been there for a couple of months! I love seeing you guys do vlogs where I live haha still waiting on the day when I run into you guys in boston!
# positive
# ...........
# are you gonna do the head of the charles this year??? i'm from boston and always wanted to go and if i could see u it would be so cool!!!
# positive
# ...........
# Aw yay I'm so excited and I can't wait to see how cute everything turns out!
# positive
# ...........
# whats the backpack line called...fall robin??
# negative
# ...........
# I'm applying to college and seriously looking at boston university. they came to my school and they have everything i could ever want from a college but i haven't actually visited it. they told me theres a better chance for me to get in early decision but that would mean if i get accepted i have to legally go there. just in your opinion, since you go to the school, is the school worth it? like i really love weather change and college towns but I'm worried if i get in and forced to go there i won't enjoy it...i could use ur input thanks <3
# positive
# ...........
# I have that same shirt I rowed in head of the Charles this year
# positive
# ...........
# ROOM TOUR PLEASE!
# negative
# ...........
# Do you have pep rallies in college
# positive
# ...........
# Did your dad do your eyebrows?
# positive
# ...........
# Hi Gretchen! I'm actually a freshman this year in Sleeper, I'm loving it so far! Could you maybe do a BU Vegan What I Eat In A Day? I'm vegan too so I could really use some tips haha. Go terriers!
# negative
# ...........
# I wondered why this video is so long... but after maaaaany uninteresting sentences she said it became clear.... lots and lots of aaaaaaads, I just wanted to see how she moves in...
# negative
# ...........
# Ya need to leave those brows alone before there's nothing left
# negative
# ...........
# wow your skin looks great!!! love you & this vlog btw:)
# negative
# ...........
# HI! I love you so much! And I live in Boston and I really want to meet you!
# positive
# ...........
# I've been waiting so long for this!! Agh!!!!??? I love you so much Gretchen!!!
# negative
# ...........
# I've been looking forward to this!!!
# negative
# ...........
# I am on a college movie in binge and i love it
# negative
# ...........
# Please do vlogmas again?
# negative
# ...........
# Taylor!!!!!!!!!!!!!!!!!1
# negative
# ...........
# is it just me or does she sound like tana moegou
# positive
# ...........
# is it me or does seh sound like tana mogeau? Love youuu
# negative
# ...........
# I just don't understand how Gretchen has almost 200,000 subscribers! The time and effort she puts in her video really deserves a million subscribers
# positive
# ...........
# does she smoke 12 packs a day to get that effect on her voice cause dang im jelous
# negative
# ...........
# I love you so much and miss your vlogs! Can you see if lucy and you gretchen can do a room tour on the vlog channel? just like a quick casual one! your room is super cute but I want to see lucys! I miss seeing her!! Love you both!!!
# positive
# ...........
# Gretchen we have the same name
# negative
# ...........
# Omg it's so nice
# positive
# ...........
# What was the name of the artist she was playing on the record player?
# positive
# ...........
# i love the kind of room that you have!
# negative
# ...........
# O
# positive
# ...........
# Does she ever shit up if so she should
# positive
# ...........
# I'm a sophomore at Ohio state this year and my living situation is really similar to yours! The building I'm living in is brand new this year (thank god) and I'm in an 8 girl suite so there's four bedrooms (2 girls per room), we have 2 bathrooms and a commons area and we have such a great location on campus! How many girls are in your suite? I think it's pretty awesome how you each have your own room in the suite!!
# positive
# ...........
# I HAVE BEEN WAITING FOR THIS FOR SO LONG  you have really inspired me to do well my sophomore year of high school ilysm?
# positive
# ...........
# I don't know why but you kinda remind me of tana mongeau? just certain facial features and your voice
# negative
# ...........
# Fjallraven translates to the mountain fox
# positive
# ...........
# Been waiting for this for so long! Liked and commented before even watching it! xo
# negative
# ...........
# YESSS im so happy :)))
# negative
# ...........
# Wow BU is too nice
# positive
# ...........
# I love you!!!!
# negative
# ...........
# Your second year suites look like normal first year accommodation in the UK
# negative
# ...........
# college dorm room tour pls!!!! ily
# negative
# ...........
# What do you edited with
# negative
# ...........
# Omg I live so close to Boston! Where did u live before college? Much love you're so pretty:))
# negative
# ...........
# You girls are so lucky ? I wish I could go and dorm as well but is just so expensive :,( I wish you all the best luck enjoy and by the way i love love love your videos!! When I am feeling sad it just make my day so much better! Keep it up!
# negative
# ...........
# Been waiting for this since the summer tbh,  clicked on this so fast and liked & commented before watching that's how much ily
# negative
# ...........
# I love your college vlogs!
# negative
# ...........
# OMG I HAVE BEEN WAITING FOR THIS VIDEO!!!!!
# negative
# ...........
# ILYSM
# positive
# ...........
# her eyebrows are so far apart they don't even share the same postal code
# positive
# ...........
# i absolutely love all your college videos!!!!
# negative
# ...........
# You look like Britney's Spears little sister
# positive
# ...........
# did they end up getting your door lock situation taken care of?
# negative
# ...........
# does anyone else think she kind of looks like niki from niki and gabi?
# negative
# ...........
# reading these comments and now realizing how ignorant people can be ??
# positive
# ...........
# You're so adorable , I love your personality ???
# positive
# ...........
# woooohoooo!!!!!!
# negative
# ...........
# Your second year suites look like normal first year accommodation in the UK
# negative
# ...........
# she must made slot of money on them sponsorships ????I thought it was going to be the hole video
# negative
# ...........
# My small liberal arts college doesn't get recognized by UNIDAY'S :'(
# positive
# ...........
# You talk really fast lol
# negative
# ...........
# OMG your dad is adorable
# positive
# ...........
# You talk well fast ???
# negative
# ...........
# you spoke wayyy too much
# positive
# ...........
# I love that you love alt j???
# negative
# ...........
# Im in my second year also and I wish I could be at BU with you! looks so fun! I commute to a local university in Michigan. Oakland University. Love you and Lucy so pretty! :)
# negative
# ...........
# She's pretty but her eyebrows bother me
# negative
# ...........
# Please film a lot about college life this year!!!
# positive
# ...........
# You totally sounded like Brooke Davis in this vlog with your scratchy voice haha hope your first week has been good and can't wait to see more of you at BU this year!! xo Ps I totally got the same headboard as you for my suite this year too and it looks SO cute
# positive
# ...........
# Dang that is a nice suite, so jealous! The apartments at my college feel like a dark creepy basement compared to this
# positive
# ...........
# how did u get into BU???
# negative
# ...........
# how far is your house from bu?
# negative
# ...........
# If you want to know when her moving part actually starts it is about 6:50
# positive
# ...........
# I have been waiting for this for sooo long!!!!!!
# negative
# ...........
# blow blow blow
# negative
# ...........
# Woooooo love your college vlogs
# positive
# ...........
# My brother graduated from BU this year
# positive
# ...........
# What kind of camera do you use for VLOGing? ?
# positive
# ...........
# I like the view from your room.
#
# Please can you do a update of Whats in your Bag?
# negative
# ...........
# Gretchen, every single time you upload a video I get so excited because I'm a sophomore in college and it feels like someone actually gets me? good luck this year!:) you got this! Much love, A.
# negative
# ...........
# Yay!!!! I'm so glad you posted this. I love your vlogs, especially your college ones. Good luck in your sophomore year!! ????
# positive
# ...........
# What is the name of the sweats?
# negative
# ...........
# Is anybody else already excited for vlogmas?
# negative
# ...........
# that looks JUST like my dorms! i go to school in Florida :)
# negative
# ...........
# You talk to much
# negative
# ...........
# where is your rug from? i've been looking for one like that for sooo long
# negative
# ...........
# for anyone who was wondering the pants are named "rewind pant black" and are $69
# positive
# ...........
# Legend says that if u are early Gretchen will reply. I love ur channel so much
# positive
# ...........
# Omg I love the kanken colour!!! I have one in cloud grey
# negative
# ...........
# I'm so excited to see your dorm tour!! also does Justin go to BU too or does he go to another school?/ how often do you get to see him!
# positive
# ...........
# Does anyone know if she has Spotify? I'd love to see what music she listens to!
# negative
# ...........
# If we click the link and sign up are we automatically entered for the contest?
# positive
# ...........
# Her                                 eyebrows
# positive
# ...........
# I can't wait to see a dorm tour!
# negative
# ...........
# loveeeee these types of vlogs!!!!
# positive
# ...........
# Girl! Wildfox lets you use UNiDAYS too!!! Either 15% or 20% but still...amazing! I've gotten baggy beach jumpers for like $60-$90 instead of $120ish! :)
# positive
# ...........
# I literally had the exact same thing happen to me and my dorm room this year (the lock issue).
# negative
# ...........
# Hi Gretchen!  I'm a freshman in high school living in Montana, and BU is my dream school.  Thanks for making these videos sharing your life at college, it really inspires me.  Love you! xx
# positive
# ...........
# your eyebrows are so far apart
# positive
# ...........
# Gretchen plleeeaaseee do a meetup in Boston!! I go to Northeastern University (very close to BU) and I would love to meet you!!!
# positive
# ...........
# Hi
# positive
# ...........
# good luck this year!!!!!!!
# negative
# ...........
# Can you do one for Lucy's dorm?!
# negative
# ...........
# Going to Boston tomorrow for a 10k!! :))
# positive
# ...........
